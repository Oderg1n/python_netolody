# %%
year = 2019

# %%
if year == 2020:
    print('Високосный год')
elif year == 2019:
    print('Обычный год')
# Out:
# Обычный год

# %%
number = 123456
if number == 123456:
    print('Несчастливый билет')
elif number == 123321:
    print('Счастливый билет')
# Out:
# Несчастливый билет
