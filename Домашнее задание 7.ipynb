# %%
from datetime import datetime

# The Moscow Times
date1 = datetime.strptime("Wednesday, October 2, 2002", "%A, %B %d, %Y")

# The Guardian
date2 = datetime.strptime("Friday, 11.10.13", "%A, %d.%m.%y")

# Daily News
date3 = datetime.strptime("Thursday, 18 August 1977", "%A, %d %B %Y")

print(date1)  # 2002-10-02 00:00:00
print(date2)  # 2013-10-11 00:00:00
print(date3)  # 1977-08-18 00:00:00
# Out:
# 2002-10-02 00:00:00
# 2013-10-11 00:00:00
# 1977-08-18 00:00:00
